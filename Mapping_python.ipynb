# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
america = gpd.read_file("data/us_state_boundaries/ne_110m_admin_1_states_provinces.shp")

# %%
type(america)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
america.head()
# Out:
#            featurecla  scalerank adm1_code  diss_me iso_3166_2  \
# 0  Admin-1 scale rank          2  USA-3537     3537      US-CT
# 1  Admin-1 scale rank          2  USA-3561     3561      US-ME
# 2  Admin-1 scale rank          2  USA-3513     3513      US-MA
# 3  Admin-1 scale rank          2  USA-3538     3538      US-NH
# 4  Admin-1 scale rank          2  USA-3539     3539      US-RI
#
#                                     wikipedia iso_a2  adm0_sr           name  \
# 0    http://en.wikipedia.org/wiki/Connecticut     US        1    Connecticut
# 1          http://en.wikipedia.org/wiki/Maine     US        6          Maine
# 2  http://en.wikipedia.org/wiki/Massachusetts     US        6  Massachusetts
# 3  http://en.wikipedia.org/wiki/New_Hampshire     US        1  New Hampshire
# 4   http://en.wikipedia.org/wiki/Rhode_Island     US        6   Rhode Island
#
#                                             name_alt  ... FCLASS_PL FCLASS_GR  \
# ...

# %%
america.plot()
# Out:
# <AxesSubplot:>

# %%
url = 'https://raw.githubusercontent.com/Rilquer/mapping_in_r/main/data/states_gdp.csv'
df = pd.read_csv(url, index_col=0)
df.head()
# Out:
#                   gdp
# name
# Connecticut    298395
# Maine           77963
# Massachusetts  641332
# New Hampshire   99673
# Rhode Island    66571

# %%
america = america.merge(df, on='name', how='right')

# %%
america.plot(column='gdp_x')
# Out:
# <AxesSubplot:>

# %%
list(america.columns)
# Out:
# ['featurecla',
#  'scalerank',
#  'adm1_code',
#  'diss_me',
#  'iso_3166_2',
#  'wikipedia',
#  'iso_a2',
#  'adm0_sr',
#  'name',
#  'name_alt',
#  'name_local',
#  'type',
#  'type_en',
#  'code_local',
#  'code_hasc',
#  'note',
#  'hasc_maybe',
#  'region',
#  'region_cod',
#  'provnum_ne',
#  'gadm_level',
#  'check_me',
#  'datarank',
#  'abbrev',
#  'postal',
#  'area_sqkm',
#  'sameascity',
#  'labelrank',
#  'name_len',
#  'mapcolor9',
#  'mapcolor13',
#  'fips',
#  'fips_alt',
#  'woe_id',
#  'woe_label',
#  'woe_name',
#  'latitude',
#  'longitude',
#  'sov_a3',
#  'adm0_a3',
#  'adm0_label',
#  'admin',
#  'geonunit',
#  'gu_a3',
#  'gn_id',
#  'gn_name',
#  'gns_id',
#  'gns_name',
#  'gn_level',
#  'gn_region',
#  'gn_a1_code',
#  'region_sub',
#  'sub_code',
#  'gns_level',
#  'gns_lang',
#  'gns_adm1',
#  'gns_region',
#  'min_label',
#  'max_label',
#  'min_zoom',
#  'wikidataid',
#  'name_ar',
#  'name_bn',
#  'name_de',
#  'name_en',
#  'name_es',
#  'name_fr',
# ...

# %%
america.boundary.plot()
# Out:
# <AxesSubplot:>
